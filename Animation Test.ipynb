# %%
from IPython.display import clear_output
import time

# %%
nx = 51
dx = 2./(nx-1)
nt = 25    
dt = .025 

u = ones(nx) 
u[.5/dx : 1/dx+1]=2

fig, ax = plt.subplots()

un = np.ones(nx)
for n in range(nt):
    ax.plot(np.linspace(0,2,nx),u)
    ax.axis((0, 2, .8, 2.2))
    un[:] = u[:]
    u[1:] = -dt/dx*(un[1:]-un[:-1])+un[1:]
    time.sleep(0.1)
    clear_output()
    display(fig)
    ax.cla()
plt.close()

# %%
def plotani(x, y):
    
    ax.plot(x, y)
    ax.axis((0, 2, .8, 2.2))
    
    time.sleep(0.1)
    clear_output()
    display(fig)
    ax.cla()

  
nx = 51
dx = 2./(nx-1)
nt = 25    
dt = .025 

u = ones(nx) 
u[.5/dx : 1/dx+1]=2
un = ones(nx)
fig, ax = plt.subplots()
for n in range(nt):
    un[:] = u[:]
    u[1:] = -dt/dx*(un[1:]-un[:-1])+un[1:]
    plotani(linspace(0,2,nx), u)
plt.close()
